# %%
import pandas as pd

# %%
v = pd.read_csv("D:/Documents/kidney_disease.csv")

# %%
v
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
g.head(5)
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
g.tail(4)
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 396  396  42.0  70.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
#
#      ...  pcv    wc   rc  htn  dm  cad appet  pe ane classification
# 396  ...   54  7800  6.2   no  no   no  good  no  no         notckd
# 397  ...   49  6600  5.4   no  no   no  good  no  no         notckd
# 398  ...   51  7200  5.9   no  no   no  good  no  no         notckd
# 399  ...   53  6800  6.1   no  no   no  good  no  no         notckd
#
# [4 rows x 26 columns]

# %%
g.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
g.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
g.size
# Out:
# 10400

# %%
g.shape
# Out:
# (400, 26)

# %%
type(g)
# Out:
# pandas.core.frame.DataFrame

# %%
len(g)
# Out:
# 400

# %%
g.loc[24:45]
# Out:
#     id   age     bp     sg   al   su       rbc        pc         pcc  \
# 24  24  42.0  100.0  1.015  4.0  0.0    normal  abnormal  notpresent
# 25  25  61.0   60.0  1.025  0.0  0.0       NaN    normal  notpresent
# 26  26  75.0   80.0  1.015  0.0  0.0       NaN    normal  notpresent
# 27  27  69.0   70.0  1.010  3.0  4.0    normal  abnormal  notpresent
# 28  28  75.0   70.0    NaN  1.0  3.0       NaN       NaN  notpresent
# 29  29  68.0   70.0  1.005  1.0  0.0  abnormal  abnormal     present
# 30  30   NaN   70.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 31  31  73.0   90.0  1.015  3.0  0.0       NaN  abnormal     present
# 32  32  61.0   90.0  1.010  1.0  1.0       NaN    normal  notpresent
# 33  33  60.0  100.0  1.020  2.0  0.0  abnormal  abnormal  notpresent
# 34  34  70.0   70.0  1.010  1.0  0.0    normal       NaN     present
# 35  35  65.0   90.0  1.020  2.0  1.0  abnormal    normal  notpresent
# 36  36  76.0   70.0  1.015  1.0  0.0    normal    normal  notpresent
# ...

# %%
g.loc[[4,6,8,54,67],["rbc","pcc","bp"]]
# Out:
#        rbc         pcc     bp
# 4   normal  notpresent   80.0
# 6      NaN  notpresent   70.0
# 8   normal     present  100.0
# 54  normal  notpresent   80.0
# 67  normal  notpresent   80.0

# %%
g.loc[(g.rbc=="normal")&(g.ba=="present"),["rbc","ba","classification"]]
# Out:
#         rbc       ba classification
# 14   normal  present            ckd
# 24   normal  present            ckd
# 34   normal  present            ckd
# 90   normal  present            ckd
# 92   normal  present            ckd
# 130  normal  present            ckd
# 176  normal  present            ckd
# 213  normal  present            ckd
# 233  normal  present            ckd
# 242  normal  present            ckd

# %%
g.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
g.isnull()
# Out:
#         id    age     bp     sg     al     su    rbc     pc    pcc     ba  \
# 0    False  False  False  False  False  False   True  False  False  False
# 1    False  False  False  False  False  False   True  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  False  False  False  False  False  False  False  False  False  False
# 396  False  False  False  False  False  False  False  False  False  False
# 397  False  False  False  False  False  False  False  False  False  False
# 398  False  False  False  False  False  False  False  False  False  False
# 399  False  False  False  False  False  False  False  False  False  False
#
#      ...    pcv     wc     rc    htn     dm    cad  appet     pe    ane  \
# ...

# %%
g.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
g.dropna(axis=1)
# Out:
#       id classification
# 0      0            ckd
# 1      1            ckd
# 2      2            ckd
# 3      3            ckd
# 4      4            ckd
# ..   ...            ...
# 395  395         notckd
# 396  396         notckd
# 397  397         notckd
# 398  398         notckd
# 399  399         notckd
#
# [400 rows x 2 columns]

# %%
g.dropna(axis=0)
# Out:
#       id   age    bp     sg   al   su       rbc        pc         pcc  \
# 3      3  48.0  70.0  1.005  4.0  0.0    normal  abnormal     present
# 9      9  53.0  90.0  1.020  2.0  0.0  abnormal  abnormal     present
# 11    11  63.0  70.0  1.010  3.0  0.0  abnormal  abnormal     present
# 14    14  68.0  80.0  1.010  3.0  2.0    normal  abnormal     present
# 20    20  61.0  80.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# ..   ...   ...   ...    ...  ...  ...       ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0    normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0    normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0    normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0    normal    normal  notpresent
#
#              ba  ...  pcv     wc   rc  htn   dm  cad appet   pe  ane  \
# ...

# %%
g["age"].mean()
# Out:
# 51.48337595907928

# %%
g["sg"].median()
# Out:
# 1.02

# %%
g["pc"].mode()[0]
# Out:
# 'normal'

# %%
#groupby

# %%
g.rbc.unique()
# Out:
# array([nan, 'normal', 'abnormal'], dtype=object)

# %%
g.groupby("rbc").count()
# Out:
#            id  age   bp   sg   al   su   pc  pcc   ba  bgr  ...  pcv   wc  \
# rbc                                                         ...
# abnormal   47   47   46   47   47   47   45   47   47   37  ...   39   30
# normal    201  201  195  201  198  198  194  198  198  188  ...  187  180
#
#            rc  htn   dm  cad  appet   pe  ane  classification
# rbc
# abnormal   25   47   47   47     47   47   47              47
# normal    174  199  199  199    200  200  200             201
#
# [2 rows x 25 columns]

# %%
g.groupby("rbc").mean()
# Out:
#                   id        age         bp        sg        al        su  \
# rbc
# abnormal  126.255319  52.030854  82.173913  1.013936  2.319149  0.659574
# normal    264.815920  48.594445  73.333333  1.019726  0.742424  0.262626
#
#                  bgr         bu        sc         sod       pot       hemo
# rbc
# abnormal  187.837838  91.479545  5.345455  132.484848  4.427273  10.131707
# normal    130.617021  50.151832  2.170103  139.587912  4.797253  13.805405

# %%
g.rbc.value_counts()
# Out:
# normal      201
# abnormal     47
# Name: rbc, dtype: int64

# %%
g.classification.value_counts()
# Out:
# ckd       248
# notckd    150
# ckd\t       2
# Name: classification, dtype: int64

# %%
g.groupby("age")["classification"].value_counts()
# Out:
# age   classification
# 2.0   ckd               1
# 3.0   ckd               1
# 4.0   ckd               1
# 5.0   ckd               2
# 6.0   ckd               1
#                        ..
# 80.0  notckd            2
# 81.0  ckd               1
# 82.0  ckd               1
# 83.0  ckd               1
# 90.0  ckd               1
# Name: classification, Length: 129, dtype: int64

# %%
#data visualization

# %%
g.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
g.plot()
# Out:
# <AxesSubplot:>

# %%
g.plot(x="sg",y="age",kind="scatter",color="green",marker="^",figsize=(10,10))
# Out:
# <AxesSubplot:xlabel='sg', ylabel='age'>

# %%
g.iloc[:,2:9].plot(kind="box",figsize=(10,10),rot=90,color="g")
# Out:
# <AxesSubplot:>

# %%
g.plot(x="wc",y="age",kind="bar",color="red")
# Out:
# <AxesSubplot:xlabel='wc'>

# %%
g.plot(x="pcv",y="age",kind="line",color="blue")
# Out:
# <AxesSubplot:xlabel='pcv'>
